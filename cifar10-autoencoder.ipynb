# %%
from keras.datasets import cifar10
from keras.layers import Input, Dense,Conv2D,MaxPooling2D,UpSampling2D,BatchNormalization
from keras.models import Model,Sequential
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
(X_train, _), (X_test, _) = cifar10.load_data()
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
X_train = X_train.reshape(len(X_train),X_train.shape[1],X_train.shape[2],3)
X_test = X_test.reshape(len(X_test), X_test.shape[1],X_test.shape[2],3)
print(X_train.shape)
print(X_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# Good for Minist Dataset

# %%
input_img = Input(shape=(32,32,3))

#Encoder
x = Conv2D(16,(3,3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(8,(3,3), activation='relu', padding='same')(x)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(8,(3,3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2,2), padding='same', name='encoder')(x)

#Decoder
x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)

x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(16, (3, 3), activation='relu',padding='same')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Good for coloured Image

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())     # 32x32x32
model.add(Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu'))      # 16x16x32
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 16x16x32
model.add(BatchNormalization())     # 16x16x32
model.add(UpSampling2D())
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 32x32x32
model.add(BatchNormalization())
model.add(Conv2D(3,  kernel_size=1, strides=1, padding='same', activation='sigmoid'))   # 32x32x3

model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 3)         99
# =================================================================
# Total params: 29,123
# Trainable params: 28,931
# Non-trainable params: 192
# _________________________________________________________________

# %%
autoencoder=Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# encoder (MaxPooling2D)       (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 3)         435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder = Model(input_img, encoded)

# %%
encoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# encoder (MaxPooling2D)       (None, 4, 4, 8)           0
# =================================================================
# Total params: 2,192
# Trainable params: 2,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, X_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.0071 - accuracy: 0.6614 - val_loss: 0.0285 - val_accuracy: 0.4623
# Epoch 2/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.0015 - accuracy: 0.7867 - val_loss: 0.0044 - val_accuracy: 0.7014
# Epoch 3/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 9.9459e-04 - accuracy: 0.8151 - val_loss: 0.0013 - val_accuracy: 0.7605
# Epoch 4/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 8.0205e-04 - accuracy: 0.8324 - val_loss: 7.6804e-04 - val_accuracy: 0.8031
# Epoch 5/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 6.8567e-04 - accuracy: 0.8437 - val_loss: 6.2194e-04 - val_accuracy: 0.8284
# Epoch 6/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 5.9135e-04 - accuracy: 0.8524 - val_loss: 5.7017e-04 - val_accuracy: 0.8092
# Epoch 7/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 5.3682e-04 - accuracy: 0.8601 - val_loss: 6.9190e-04 - val_accuracy: 0.8639
# Epoch 8/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 4.9690e-04 - accuracy: 0.8651 - val_loss: 5.3812e-04 - val_accuracy: 0.8316
# Epoch 9/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 4.8568e-04 - accuracy: 0.8665 - val_loss: 4.8782e-04 - val_accuracy: 0.8669
# Epoch 10/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 4.4812e-04 - accuracy: 0.8751 - val_loss: 5.0769e-04 - val_accuracy: 0.8411
# Epoch 11/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 4.4439e-04 - accuracy: 0.8758 - val_loss: 4.5169e-04 - val_accuracy: 0.8644
# Epoch 12/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 4.0691e-04 - accuracy: 0.8793 - val_loss: 3.7113e-04 - val_accuracy: 0.8654
# Epoch 13/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 3.8596e-04 - accuracy: 0.8807 - val_loss: 3.1245e-04 - val_accuracy: 0.8835
# Epoch 14/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 3.7893e-04 - accuracy: 0.8843 - val_loss: 4.0157e-04 - val_accuracy: 0.8936
# Epoch 15/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 3.7765e-04 - accuracy: 0.8841 - val_loss: 4.3213e-04 - val_accuracy: 0.8808
# Epoch 16/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 3.4584e-04 - accuracy: 0.8854 - val_loss: 3.3321e-04 - val_accuracy: 0.8975
# Epoch 17/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 3.5183e-04 - accuracy: 0.8852 - val_loss: 4.4619e-04 - val_accuracy: 0.8772
# Epoch 18/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 3.4363e-04 - accuracy: 0.8850 - val_loss: 2.4579e-04 - val_accuracy: 0.8914
# Epoch 19/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 3.3808e-04 - accuracy: 0.8884 - val_loss: 3.4803e-04 - val_accuracy: 0.8559
# Epoch 20/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 3.1335e-04 - accuracy: 0.8890 - val_loss: 3.3432e-04 - val_accuracy: 0.8501
# Epoch 21/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 3.2241e-04 - accuracy: 0.8879 - val_loss: 3.6418e-04 - val_accuracy: 0.8767
# Epoch 22/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 3.0601e-04 - accuracy: 0.8888 - val_loss: 2.2940e-04 - val_accuracy: 0.8867
# Epoch 23/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 2.9153e-04 - accuracy: 0.8918 - val_loss: 4.0377e-04 - val_accuracy: 0.8462
# Epoch 24/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 3.1238e-04 - accuracy: 0.8918 - val_loss: 4.0103e-04 - val_accuracy: 0.8858
# Epoch 25/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 3.1164e-04 - accuracy: 0.8924 - val_loss: 3.8088e-04 - val_accuracy: 0.9058
# Epoch 26/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.8631e-04 - accuracy: 0.8950 - val_loss: 5.7215e-04 - val_accuracy: 0.8941
# Epoch 27/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 2.8356e-04 - accuracy: 0.8939 - val_loss: 2.6366e-04 - val_accuracy: 0.9097
# Epoch 28/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 2.6846e-04 - accuracy: 0.8972 - val_loss: 2.6735e-04 - val_accuracy: 0.8791
# Epoch 29/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.7804e-04 - accuracy: 0.8944 - val_loss: 2.1864e-04 - val_accuracy: 0.9026
# Epoch 30/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 2.6474e-04 - accuracy: 0.8962 - val_loss: 2.1413e-04 - val_accuracy: 0.8930
# Epoch 31/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.6089e-04 - accuracy: 0.8973 - val_loss: 3.9265e-04 - val_accuracy: 0.8731
# Epoch 32/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.5253e-04 - accuracy: 0.8974 - val_loss: 2.2693e-04 - val_accuracy: 0.9128
# Epoch 33/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.5510e-04 - accuracy: 0.8982 - val_loss: 2.8639e-04 - val_accuracy: 0.8880
# Epoch 34/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 2.7456e-04 - accuracy: 0.8968 - val_loss: 2.4067e-04 - val_accuracy: 0.8734
# Epoch 35/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.4896e-04 - accuracy: 0.8987 - val_loss: 2.6542e-04 - val_accuracy: 0.8951
# Epoch 36/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.5206e-04 - accuracy: 0.8978 - val_loss: 2.8348e-04 - val_accuracy: 0.8930
# Epoch 37/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.5183e-04 - accuracy: 0.9015 - val_loss: 3.0535e-04 - val_accuracy: 0.8683
# Epoch 38/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.4863e-04 - accuracy: 0.9006 - val_loss: 6.8485e-04 - val_accuracy: 0.8254
# Epoch 39/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 2.5407e-04 - accuracy: 0.8989 - val_loss: 4.3939e-04 - val_accuracy: 0.8327
# Epoch 40/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.4278e-04 - accuracy: 0.8984 - val_loss: 9.9267e-04 - val_accuracy: 0.8761
# Epoch 41/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.3848e-04 - accuracy: 0.9006 - val_loss: 2.2353e-04 - val_accuracy: 0.9109
# Epoch 42/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 2.4410e-04 - accuracy: 0.9003 - val_loss: 5.5283e-04 - val_accuracy: 0.8816
# Epoch 43/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 2.3091e-04 - accuracy: 0.9009 - val_loss: 5.4023e-04 - val_accuracy: 0.9008
# Epoch 44/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.3399e-04 - accuracy: 0.9007 - val_loss: 2.5508e-04 - val_accuracy: 0.8729
# Epoch 45/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.4382e-04 - accuracy: 0.8990 - val_loss: 6.2773e-04 - val_accuracy: 0.8799
# Epoch 46/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 2.0980e-04 - accuracy: 0.9019 - val_loss: 2.0387e-04 - val_accuracy: 0.8695
# Epoch 47/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 2.0671e-04 - accuracy: 0.9034 - val_loss: 3.4747e-04 - val_accuracy: 0.8896
# Epoch 48/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.2166e-04 - accuracy: 0.9022 - val_loss: 2.9983e-04 - val_accuracy: 0.8577
# Epoch 49/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.2250e-04 - accuracy: 0.9010 - val_loss: 5.6561e-04 - val_accuracy: 0.8775
# Epoch 50/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.1554e-04 - accuracy: 0.9004 - val_loss: 2.5405e-04 - val_accuracy: 0.9153

# %%
#encoded_imgs = model.predict(X_test)
predicted = model.predict(X_test)

# %%
plt.figure(figsize=(40,4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    
    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  
    
plt.show()
